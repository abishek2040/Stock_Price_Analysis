# %%
import yfinance as yf
import plotly.express as px
import pandas as pd

# %%
tickers = ["AAPL", "MSFT", "AMZN", "NWG.L", "BARC.L", "HSBA.L", "BP.L", "GSK.L", "VOD.L"]
data = yf.download(tickers, start="2018-01-01", end="2024-01-01")
data.head()
# Out:
# [*********************100%***********************]  9 of 9 completed
# Price           Close                                                  \
# Ticker           AAPL       AMZN      BARC.L        BP.L        GSK.L
# Date
# 2018-01-02  40.267082  59.450500  202.695938  515.156494  1325.708252
# 2018-01-03  40.260059  60.209999  203.194656  521.826233  1347.171753
# 2018-01-04  40.447067  60.479500  203.992752  527.599792  1343.561035
# 2018-01-05  40.907570  61.457001  198.685883  527.201843  1365.024536
# 2018-01-08  40.755630  62.343498  199.603638  525.011719  1357.401855
#
# Price                                                           High  ...  \
# Ticker          HSBA.L       MSFT       NWG.L       VOD.L       AAPL  ...
# Date                                                                  ...
# 2018-01-02  761.750977  78.870338  297.212463  232.540466  40.276435  ...
# 2018-01-03  760.058411  79.237396  295.283234  232.192352  40.802379  ...
# 2018-01-04  762.746643  79.934807  297.962830  234.032379  40.549921  ...
# 2018-01-05  760.158142  80.925850  296.140656  235.524292  40.994059  ...
# 2018-01-08  754.682190  81.008446  298.713043  236.369690  41.050164  ...
#
# Price             Open       Volume                                      \
# Ticker           VOD.L         AAPL        AMZN      BARC.L        BP.L
# Date
# 2018-01-02  233.883184  102223600.0  53890000.0  23759135.0  20152548.0
# 2018-01-03  233.137231  118071600.0  62176000.0  26003107.0  27207749.0
# 2018-01-04  232.988033   89738400.0  60442000.0  41817624.0  32592520.0
# 2018-01-05  234.728599   94640000.0  70894000.0  58768373.0  24779506.0
# 2018-01-08  235.325359   82271200.0  85590000.0  55607013.0  29326873.0
#
# Price
# Ticker           GSK.L      HSBA.L        MSFT       NWG.L       VOD.L
# Date
# 2018-01-02   8242323.0  14948356.0  22483800.0   6379825.0  28518111.0
# 2018-01-03   9407654.0  17643845.0  26061400.0   9898966.0  36335155.0
# 2018-01-04  11053203.0  21951829.0  21912000.0  11219873.0  65362950.0
# 2018-01-05  10555810.0  19200215.0  23407100.0   9216364.0  69338309.0
# 2018-01-08  11274454.0  22109518.0  22113000.0  11262991.0  58835938.0
#
# [5 rows x 45 columns]

# %%
# Inspecting the structure of the data
print(data.shape)

# Checking any missing values
print(data.isnull().sum().to_frame().T)
data = data.dropna()

# Printing the shape after dropping missing values
print(data.shape)
# Out:
# (1544, 45)
# Price  Close                                                High  ...  Open  \
# Ticker  AAPL AMZN BARC.L BP.L GSK.L HSBA.L MSFT NWG.L VOD.L AAPL  ... VOD.L
# 0         35   35     30   30    30     30   35    30    30   35  ...    30
#
# Price  Volume
# Ticker   AAPL AMZN BARC.L BP.L GSK.L HSBA.L MSFT NWG.L VOD.L
# 0          35   35     30   30    30     30   35    30    30
#
# [1 rows x 45 columns]
# (1479, 45)

# %%
print(data.describe())

# Getting the highest priced stock among all the stocks in the dataset; 
print("\nHighest closing price among all stocks:")
print(data["Close"].max().max())
# Out:
# Price         Close                                                      \
# Ticker         AAPL         AMZN       BARC.L         BP.L        GSK.L
# count   1479.000000  1479.000000  1479.000000  1479.000000  1479.000000
# mean     107.353220   119.985667   160.728864   432.041644  1512.619839
# std       50.796248    33.405657    27.536971   102.810553   137.945636
# min       33.736988    59.450500    80.094299   192.899658  1196.858154
# 25%       51.092756    90.649998   147.411804   328.013214  1406.029663
# 50%      119.590324   113.790001   160.255814   468.091705  1499.797119
# 75%      149.341103   154.467499   180.073364   516.770294  1611.940002
# max      195.892593   186.570496   216.742172   595.840088  1853.840454
#
# Price                                                              High  ...  \
# Ticker       HSBA.L         MSFT        NWG.L        VOD.L         AAPL  ...
# count   1479.000000  1479.000000  1479.000000  1479.000000  1479.000000  ...
# mean     543.210499   205.102418   229.764135   128.699456   108.488669  ...
# std      115.723996    82.765832    48.668153    34.465465    51.276459  ...
# min      282.435852    78.007767   100.141418    64.640465    34.574540  ...
# 25%      436.465195   127.152939   214.421310   108.902920    51.935671  ...
# 50%      561.888733   210.889236   236.901199   126.364212   121.118180  ...
# 75%      636.488678   273.999786   263.128220   147.619476   151.354050  ...
# max      792.515869   376.219177   324.114929   236.717804   197.385687  ...
#
# Price          Open        Volume                                            \
# Ticker        VOD.L          AAPL          AMZN        BARC.L          BP.L
# count   1479.000000  1.479000e+03  1.479000e+03  1.479000e+03  1.479000e+03
# mean     128.844679  1.074936e+08  8.192956e+07  5.166462e+07  4.932035e+07
# std       34.545154  5.526766e+07  3.938698e+07  3.087654e+07  2.609138e+07
# min       65.938865  2.404830e+07  1.762600e+07  1.549882e+06  6.020955e+06
# 25%      109.064326  7.075800e+07  5.557230e+07  3.097259e+07  3.270559e+07
# 50%      126.407348  9.329200e+07  7.044200e+07  4.316398e+07  4.214000e+07
# 75%      147.699113  1.280911e+08  9.719000e+07  6.180575e+07  5.832988e+07
# max      237.215110  4.265100e+08  3.113460e+08  3.090711e+08  2.574570e+08
#
# Price
# Ticker         GSK.L        HSBA.L          MSFT         NWG.L         VOD.L
# count   1.479000e+03  1.479000e+03  1.479000e+03  1.479000e+03  1.479000e+03
# mean    9.461522e+06  3.107046e+07  2.988597e+07  2.160378e+07  9.477042e+07
# std     4.923790e+06  1.784620e+07  1.258935e+07  1.475705e+07  6.654612e+07
# min     1.976760e+05  3.833136e+06  8.989200e+06  3.728740e+05  1.395120e+06
# 25%     6.359950e+06  2.002763e+07  2.190960e+07  1.329213e+07  5.791791e+07
# 50%     8.217838e+06  2.635456e+07  2.665340e+07  1.833089e+07  7.830540e+07
# 75%     1.100642e+07  3.586333e+07  3.369745e+07  2.572682e+07  1.104360e+08
# max     4.539564e+07  1.769065e+08  1.112421e+08  3.003737e+08  9.423232e+08
#
# [8 rows x 45 columns]
#
# Highest closing price among all stocks:
# 1853.8404541015625

# %%
# Plotting the prices of the stocks over time
fig = px.line(data["Close"], title="Stock Closing Prices Over Time")
fig.show()
